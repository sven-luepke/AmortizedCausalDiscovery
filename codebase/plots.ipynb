# %% [markdown]
# ### Figure 6

# %%
import matplotlib.pyplot as plt

def plot_metric_per_num_influenced(metrics, metric_name):
    # Data for the plot
    x = [0, 1, 2, 3, 4]

    # Plot each line
    plt.figure(figsize=(4, 3))
    for model, values in metrics.items():
        plt.plot(x, values, label=model)

    # Add labels and legend
    plt.xticks(x)
    plt.xlabel("#time-series influenced by unobserved one")
    plt.ylabel(metric_name)
    plt.legend(loc="lower left")
    plt.show()

# %%
plot_metric_per_num_influenced(
    metrics={
        "ACD with Latent": [0.9864032273, 0.9827259893, 0.9671185725, 0.9538434163, 0.9277758025],
        "Mean": [0.9865775187, 0.9793426821, 0.9481512922, 0.9098063268, 0.8546339627]
    },
    metric_name="AUROC"
)

# %%
plot_metric_per_num_influenced(
    metrics={
        "ACD with Latent": [0.9944172113, 0.9369632313, 0.9011735232, 0.8833333333, 0.8566176471],
        "Mean": [0.9906045752, 0.9355877617, 0.8826257032, 0.8346000000, 0.7787309368],
    },
    metric_name="Accuracy"
)

# %%
plot_metric_per_num_influenced(
    metrics={
        "ACD with Latent": [0.0052471366, 0.0070143654, 0.0083479146, 0.0097790286, 0.0104522426],
        "Mean": [0.0063626827, 0.0085350191, 0.0119105941, 0.0138772037, 0.0148720900]
    },
    metric_name="MSE"
)
